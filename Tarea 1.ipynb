# %% [markdown]
# Mi nombre es camila, voy en el tercer semestre de Ingeniería Financiera. Un tema que me han dicho se usa bastante en mi carrera es por medio de calculo multivariable descubrir el mínimo la situación que hayas graficado

# %% [markdown]
# # Ejemplo Título

# %% [markdown]
# ## Subtítulo

# %% [markdown]
# <p>Documento de texto<p/>
# <p>Párrafo 2<p/>
# <p>Hola Mundo<p/>
# Gatos

# %% [markdown]
# Mi Nombre es **Camila**

# %% [markdown]
# *Hola Mundo*

# %% [markdown]
# ~Hola Mundo~

# %% [markdown]
# ![la-borra04.jpg](attachment:la-borra04.jpg)

# %% [markdown]
# 1. Lista
# 2. Ejemplo
# 3. Markdown

# %% [markdown]
# 1. Lista
#     1. Sublista
#     2. Sublista
# 2. Lista

# %% [markdown]
# - Lista de viñetas
# - Hola

# %% [markdown]
# $ x = 2 $

# %% [markdown]
# $$ y = \frac{x^2}{\sqrt{x}} $$

# %% [markdown]
# $ x = y+3(5) $
